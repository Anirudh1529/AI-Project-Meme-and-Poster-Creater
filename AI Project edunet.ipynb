# %% [markdown]
# <a href="https://colab.research.google.com/github/Anirudh1529/AI-Project-Meme-and-Poster-Creater/blob/main/AI%20Project%20edunet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Project Outline: AI Meme & Poster Creator
#
# This project aims to build an AI-powered tool for generating memes and posters. We'll approach this in several manageable steps:
#
# 1.  **Project Setup**: Initialize our environment and create a basic Streamlit application.
# 2.  **Core UI Development**: Build the user interface using Streamlit for inputting text, selecting images/templates, and displaying results.
# 3.  **AI Integration (Caption Generation)**: Integrate a large language model (LLM) to generate creative captions for memes and posters. This will likely be the most complex part, and we'll start with a simpler text generation model.
# 4.  **Image Handling/Templates**: Allow users to upload their own images or select from predefined templates.
# 5.  **Deployment Preparation**: Prepare the application for deployment on Streamlit Sharing and version control with GitHub.
#
# Let's start with the very first step: setting up your environment and a basic Streamlit app.

# %% [markdown]
# ### Step 1: Environment Setup and Basic Streamlit App
#
# First, we need to install `streamlit`, which is a powerful library for creating web applications in Python with minimal code. We'll also install `google-generativeai` later for the AI part, but for now, just Streamlit.

# %%
# Install Streamlit
# !pip install streamlit -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 71.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 91.7 MB/s eta 0:00:00

# %% [markdown]
# Now, let's create a very basic Streamlit application. You'll save this code in a Python file (e.g., `app.py`) for local execution, or run it directly in Colab for testing. This simple app will just display some text.

# %%
import streamlit as st

st.set_page_config(layout="wide")

st.title("Welcome to your AI Meme & Poster Creator!")
st.write("This is your very first Streamlit application. We'll build on this!")

# To run this in a local environment:
# 1. Save the above code to a file named `app.py`.
# 2. Open your terminal or command prompt.
# 3. Navigate to the directory where you saved `app.py`.
# 4. Run the command: `streamlit run app.py`
#
# In Google Colab, you would typically use `!streamlit run app.py & npx localtunnel --port 8501`
# but for a basic demo, we'll just show the code for now.
# You can also use `st.text()` for simple text output or `st.write()` for more flexibility.
# Out:
# 2026-06-15 13:26:36.428 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-15 13:26:36.430 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-15 13:26:36.663
# ...
#   command:
#
#     streamlit run /usr/local/lib/python3.12/dist-packages/colab_kernel_launcher.py [ARGUMENTS]
# 2026-06-15 13:26:36.664 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-15 13:26:36.665 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-15 13:26:36.666 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %% [markdown]
# To see this application in action within Colab, you would typically use a tool like `localtunnel` to expose the Streamlit app. However, for a step-by-step introduction, I'm providing the code structure first. Once you have a more substantial application, I can guide you on how to run it interactively in Colab or locally.

# %% [markdown]
# ### Step 2: Run Streamlit App with `localtunnel` in Colab
#
# First, we need to install `localtunnel` to create a public URL for our Streamlit app. Then, we'll save our Streamlit code to a file named `app.py` and run it with `streamlit run` combined with `localtunnel`.

# %%
# Install localtunnel
# !npm install -g localtunnel
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸
# added 22 packages in 3s
# ⠸
# ⠸3 packages are looking for funding
# ⠸  run `npm fund` for details
# ⠸

# %% [markdown]
# Next, we'll write the Streamlit application code to a file named `app.py`. This is necessary because `streamlit run` expects a file.

# %%
# %%writefile app.py
import streamlit as st

st.set_page_config(layout="wide")

st.title("Welcome to your AI Meme & Poster Creator!")
st.write("This is your very first Streamlit application. We'll build on this!")
# Out:
# Writing app.py

# %% [markdown]
# Now, let's run the Streamlit app using `streamlit run app.py` and expose it via `localtunnel` on port 8501. This cell will keep running as long as your Streamlit app is active. You'll see a public URL printed, which you can open in a new browser tab to view your app.

# %%
# !streamlit run app.py & npx localtunnel --port 8501
# Out:
# ⠙
# ...
#
# ⠹⠸⠼⠴⠦⠧2026-06-15 13:27:05.626 Uvicorn server started on 0.0.0.0:8501
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.83.163.76:8501
#
# your url is: https://tall-moose-clean.loca.lt
#   Stopping...
# ^C

# %% [markdown]
# You should now see a public URL in the output of the cell above. Click on that URL to open your Streamlit application in a new browser tab. You might get a warning about an unverified tunnel; you can just click to proceed.
#
# Once you've seen your app, you can stop the execution of the previous cell (by clicking the square stop button next to the cell) to move on. What would you like to do next? We can start adding more features to your Streamlit app, or integrate some AI capabilities.

# %% [markdown]
# ### Step 3: Adding Core UI Elements to Streamlit App
#
# We will now enhance `app.py` by adding a text input for meme/poster captions and a file uploader for images. This will allow users to interact with the application and provide content.

# %%
# %%writefile app.py
import streamlit as st

st.set_page_config(layout="wide")

st.title("AI Meme & Poster Creator")
st.write("Generate creative memes and posters with AI-powered captions!")

st.subheader("1. Enter Your Caption Idea")
caption_input = st.text_area("Start typing your caption or idea here:", "A funny caption for a meme...")

st.subheader("2. Upload Your Image")
uploaded_file = st.file_uploader("Choose an image file (PNG, JPG, JPEG)", type=["png", "jpg", "jpeg"])

st.subheader("Preview (Coming Soon!)")
if uploaded_file is not None:
    st.image(uploaded_file, caption="Uploaded Image", use_column_width=True)
else:
    st.info("Upload an image to see a preview here.")

st.subheader("Generated Meme/Poster (Coming Soon!)")
st.write("Your AI-generated content will appear here.")

st.button("Generate Meme/Poster")
# Out:
# Overwriting app.py

# %% [markdown]
# After running the cell above, the `app.py` file will be updated. You'll need to re-run the `localtunnel` cell (the one starting with `!streamlit run app.py & npx localtunnel --port 8501`) to see these changes in your Streamlit app. Remember to stop the previous `localtunnel` execution first.
#
# Once you've updated `app.py` and re-launched the app, you'll see the new input fields. What would you like to do after verifying these UI elements? We can move on to integrating the AI for caption generation or work on image processing.

# %% [markdown]
# #### 4.1 Set up Google Generative AI
#
# To use the Gemini API for caption generation, you'll need an API key. If you don't already have one, create a key in [Google AI Studio](https://makersuite.google.com/k/api). In Colab, it's best practice to add the key to the secrets manager (the "🔑" icon in the left panel) and give it the name `GOOGLE_API_KEY`. Then, you can securely access it in your code.
#
# First, let's install the `google-generativeai` library.

# %%
# Install the Google Generative AI library
# !pip install -q google-generativeai

# %% [markdown]
# Now, let's load the API key from Colab's secrets manager and initialize the Generative Model. This code should ideally be run once to configure the API.

# %%
import google.generativeai as genai
from google.colab import userdata

# Access your API key from Colab's secrets manager
GOOGLE_API_KEY=userdata.get('GOOGLE_API_KEY')
genai.configure(api_key=GOOGLE_API_KEY)

# Initialize the Generative Model
gemini_model = genai.GenerativeModel('gemini-pro') # Using 'gemini-pro' for text generation
# Out:
# /usr/local/lib/python3.12/dist-packages/google/colab/_import_hooks/_hook_injector.py:55: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   loader.exec_module(module)

# %% [markdown]
# With the model initialized, we can now integrate it into our `app.py` to generate captions. We'll modify the `app.py` file to include a function that uses `gemini_model` to generate text and display it in the Streamlit app when the 'Generate Meme/Poster' button is clicked.

# %%
# %%writefile app.py
import streamlit as st
import google.generativeai as genai
import os

# Configure Gemini API (this part will be externalized or handled by an environment variable in a real deployment)
# For local testing, you might directly use your API key here, but in Colab, it's better to use userdata.get()
# For now, we'll assume the API key is configured globally or passed via environment variables

st.set_page_config(layout="wide")

st.title("AI Meme & Poster Creator")
st.write("Generate creative memes and posters with AI-powered captions!")

st.subheader("1. Enter Your Caption Idea")
caption_input = st.text_area("Start typing your caption or idea here:", "A funny caption for a meme...")

st.subheader("2. Upload Your Image")
uploaded_file = st.file_uploader("Choose an image file (PNG, JPG, JPEG)", type=["png", "jpg", "jpeg"])

# Placeholder for AI model initialization (will be done globally in Colab or via env vars in deployment)
# For now, let's simulate the model call

def generate_caption(prompt):
    try:
        # In a real scenario, you'd initialize the model here if not global or pass it
        # For this example, we'll assume 'gemini_model' is configured externally or before this call.
        # If running locally, you might need:
        # from dotenv import load_dotenv
        # load_dotenv()
        # genai.configure(api_key=os.getenv("GOOGLE_API_KEY"))
        # model = genai.GenerativeModel('gemini-pro')

        # This part simulates the model's response based on the prompt
        # For actual generation, 'gemini_model.generate_content(prompt).text' would be used.
        # Since app.py is run independently, we'll mock the response for now.
        return f"AI-generated caption for: '{prompt}'" + "\nThis is a placeholder. Actual AI generation will be integrated soon!"
    except Exception as e:
        return f"Error generating caption: {e}. Please ensure your API key is set up correctly."



if st.button("Generate Meme/Poster"):
    if caption_input:
        with st.spinner("Generating caption..."):
            # In a deployed app or local run, the API key would be read from env vars
            # and the model would be initialized. For now, we'll just show the placeholder behavior.
            # You would replace this with actual Gemini API call:
            # generated_text = gemini_model.generate_content(caption_input).text
            generated_text = generate_caption(caption_input)
            st.subheader("Generated Caption")
            st.write(generated_text)
    else:
        st.warning("Please enter some text for the caption.")

st.subheader("Preview (Coming Soon!)")
if uploaded_file is not None:
    st.image(uploaded_file, caption="Uploaded Image", use_column_width=True)
else:
    st.info("Upload an image to see a preview here.")

st.subheader("Generated Meme/Poster (Coming Soon!)")
st.write("Your AI-generated content will appear here.")
# Out:
# Overwriting app.py

# %% [markdown]
# After running the cells above, your `app.py` will be updated with the AI integration. **Remember to re-run the `localtunnel` cell** (`!streamlit run app.py & npx localtunnel --port 8501`) to see these changes in your Streamlit app.
#
# Once the app is running, try entering a caption idea and clicking 'Generate Meme/Poster'. Initially, it will show a placeholder response, as the `app.py` itself cannot directly access the `gemini_model` object initialized in the Colab notebook. We'll address how to properly integrate the `gemini_model` for actual generation in the Streamlit app later, either by passing it or re-initializing it within `app.py` using environment variables. For now, the focus is on integrating the UI and the call flow.
#
# Let me know when you've re-launched the app and verified the button and placeholder text generation works!

# %%
# %%writefile app.py
import streamlit as st
import google.generativeai as genai
import os
# from google.colab import userdata # This is Colab-specific, remove for Streamlit Cloud

st.set_page_config(layout="wide")

st.title("AI Meme & Poster Creator")
st.write("Generate creative memes and posters with AI-powered captions!")

# Configure Gemini API
# In a deployed Streamlit app, you would typically set this as an environment variable.
# For Colab, we'll fetch it from userdata and set it as an env var for the subprocess.
# If running locally, ensure GOOGLE_API_KEY is in your environment or a .env file.

# Ensure GOOGLE_API_KEY is available for genai.configure()
# This part needs careful handling when running with `streamlit run` subprocess.
# For this demonstration, we'll ensure it's set as an environment variable.

# Initialize the Generative Model within app.py
try:
    # Get API key from environment variable (expected when 'streamlit run' is called)
    api_key = os.getenv("GOOGLE_API_KEY")
    # Removed fallback to userdata.get() as it's Colab-specific

    if api_key:
        genai.configure(api_key=api_key)
        # Using 'gemini-pro-vision' if you want image understanding capabilities later
        # For text generation, 'gemini-pro' is sufficient.
        model = genai.GenerativeModel('gemini-pro')
    else:
        st.error("Google API Key not found. Please set 'GOOGLE_API_KEY' in Streamlit Cloud secrets or environment variables.")
        model = None # Indicate that model is not available
except Exception as e:
    st.error(f"Error configuring Gemini API: {e}")
    model = None


def generate_caption(prompt_text, current_model):
    if current_model is None:
        return "AI model not configured. Cannot generate caption."
    try:
        response = current_model.generate_content(prompt_text)
        return response.text
    except Exception as e:
        return f"Error generating caption: {e}. Check your API key and model access."


st.subheader("1. Enter Your Caption Idea")
caption_input = st.text_area("Start typing your caption or idea here:", "A funny caption for a meme...")

st.subheader("2. Upload Your Image")
uploaded_file = st.file_uploader("Choose an image file (PNG, JPG, JPEG)", type=["png", "jpg", "jpeg"])

if st.button("Generate Meme/Poster"):
    if caption_input:
        with st.spinner("Generating caption..."):
            generated_text = generate_caption(caption_input, model)
            st.subheader("Generated Caption")
            st.write(generated_text)
    else:
        st.warning("Please enter some text for the caption.")

st.subheader("Preview (Coming Soon!)")
if uploaded_file is not None:
    st.image(uploaded_file, caption="Uploaded Image", use_column_width=True)
else:
    st.info("Upload an image to see a preview here.")

st.subheader("Generated Meme/Poster (Coming Soon!")
st.write("Your AI-generated content will appear here.")
# Out:
# Overwriting app.py

# %% [markdown]
# Now that `app.py` is updated to directly use the Gemini model, we need to rerun `localtunnel` while also passing the `GOOGLE_API_KEY` as an environment variable. We can do this by exporting the key before running the `streamlit` command. This will make the API key available to the `app.py` process.

# %%
import os
from google.colab import userdata

# Get API key from Colab's secrets and set it as an environment variable
os.environ["GOOGLE_API_KEY"] = userdata.get('GOOGLE_API_KEY')

# Now run Streamlit with localtunnel
# !streamlit run app.py & npx localtunnel --port 8501
# Out:
# ⠙
# ...
#
# ⠹⠸⠼⠴⠦⠧your url is: https://some-dodos-change.loca.lt
# 2026-06-15 13:34:56.658 Uvicorn server started on 0.0.0.0:8501
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.83.163.76:8501
#
# /content/app.py:2: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   import google.generativeai as genai
#   Stopping...
# ^C

# %% [markdown]
# After running the cells above, **re-run the last code cell** (the one that sets the environment variable and runs Streamlit). You should see a new `localtunnel` URL. Open it, enter a caption idea, and click 'Generate Meme/Poster'. This time, you should get a real AI-generated response!
#
# Once you've verified that the AI is generating captions, let me know. We can then discuss integrating the image with the caption to create the final meme/poster, or how to save and share your project on GitHub and Streamlit Cloud.

# %%
# Install Pillow for image processing
# !pip install -q Pillow

# %% [markdown]
# Now, we will modify `app.py` to handle the uploaded image, overlay the generated caption onto it, and then display the final image. This involves using `PIL.Image` and `PIL.ImageDraw` to add text to the image.

# %%
# %%writefile app.py
import streamlit as st
import google.generativeai as genai
import os
from PIL import Image, ImageDraw, ImageFont
from io import BytesIO
# from google.colab import userdata # This is Colab-specific, remove for Streamlit Cloud

st.set_page_config(layout="wide")

st.title("AI Meme & Poster Creator")
st.write("Generate creative memes and posters with AI-powered captions!")

# Initialize the Generative Model within app.py
try:
    api_key = os.getenv("GOOGLE_API_KEY")
    # Removed fallback to userdata.get() as it's Colab-specific

    if api_key:
        genai.configure(api_key=api_key)
        model = genai.GenerativeModel('gemini-pro')
    else:
        st.error("Google API Key not found. Please set 'GOOGLE_API_KEY' in Streamlit Cloud secrets or environment variables.")
        model = None
except Exception as e:
    st.error(f"Error configuring Gemini API: {e}")
    model = None


def generate_caption(prompt_text, current_model):
    if current_model is None:
        return "AI model not configured. Cannot generate caption."
    try:
        response = current_model.generate_content(prompt_text)
        return response.text
    except Exception as e:
        return f"Error generating caption: {e}. Check your API key and model access."

# Function to create a meme/poster image
def create_meme(image, caption_text):
    img = Image.open(image).convert("RGBA")
    img_width, img_height = img.size

    # Make image editable
    draw = ImageDraw.Draw(img)

    # Define font (you might need to adjust path/name depending on environment)
    try:
        font = ImageFont.truetype("arial.ttf", 36) # Common font, adjust size
    except IOError:
        font = ImageFont.load_default() # Fallback to default if arial.ttf is not found

    # Calculate text size and position
    text_width, text_height = draw.textsize(caption_text, font)
    x = (img_width - text_width) / 2
    y = img_height - text_height - 10 # Position at bottom, with some padding

    # Add white rectangle behind text for better readability (optional)
    draw.rectangle(((x-5, y-5), (x + text_width + 5, y + text_height + 5)), fill="white")

    # Add text to image
    draw.text((x, y), caption_text, font=font, fill="black") # Black text on white background

    # Convert back to RGB for Streamlit display
    img = img.convert("RGB")

    return img

st.subheader("1. Enter Your Caption Idea")
caption_input = st.text_area("Start typing your caption or idea here:", "A funny caption for a meme...")

st.subheader("2. Upload Your Image")
uploaded_file = st.file_uploader("Choose an image file (PNG, JPG, JPEG)", type=["png", "jpg", "jpeg"])

if st.button("Generate Meme/Poster"):
    if not caption_input:
        st.warning("Please enter some text for the caption.")
    if uploaded_file is None:
        st.warning("Please upload an image.")

    if caption_input and uploaded_file is not None:
        with st.spinner("Generating caption and image..."):
            # Generate caption
            generated_text = generate_caption(caption_input, model)
            st.subheader("Generated Caption")
            st.write(generated_text)

            # Create meme with image and generated caption
            try:
                meme_image = create_meme(uploaded_file, generated_text)
                st.subheader("Generated Meme/Poster")
                st.image(meme_image, caption="Your AI-generated creation!", use_column_width=True)
            except Exception as e:
                st.error(f"Error creating meme: {e}")

st.subheader("Preview of Uploaded Image")
if uploaded_file is not None:
    st.image(uploaded_file, caption="Uploaded Image", use_column_width=True)
else:
    st.info("Upload an image to see a preview here.")
# Out:
# Overwriting app.py

# %% [markdown]
# After running the cells above, your `app.py` will be updated with the image processing logic. **Remember to re-run the `localtunnel` cell** (the one starting with `import os` and `!streamlit run app.py & npx localtunnel --port 8501`) to see these changes in your Streamlit app.
#
# Once the app is running, try uploading an image, entering a caption idea, and clicking 'Generate Meme/Poster'. You should now see both the AI-generated caption and the final image with the caption overlaid on it!
#
# Let me know once you've successfully generated a meme/poster. Then we can proceed to preparing your project for deployment on GitHub and Streamlit Cloud.

# %% [markdown]
# #### 7.1 Create `requirements.txt`
#
# Streamlit Cloud needs to know which libraries to install to run your application. We'll create a `requirements.txt` file listing `streamlit`, `google-generativeai`, and `Pillow`.

# %%
# %%writefile requirements.txt
# streamlit
# google-generativeai
# Pillow
# Out:
# Writing requirements.txt

# %% [markdown]
# #### 7.2 Set up Git and GitHub
#
# Now, let's initialize a Git repository, add your files, and commit them. You'll need to create a new, empty repository on GitHub (e.g., named `ai-meme-poster-creator`). Replace `YOUR_GITHUB_USERNAME` and `YOUR_REPOSITORY_NAME` with your actual GitHub details.

# %%
# Initialize a Git repository
# !git init

# Add your files
# !git add app.py requirements.txt

# Commit your changes
# !git commit -m "Initial commit: AI Meme & Poster Creator Streamlit app"

# (Optional: Configure your Git username and email if you haven't already)
# !git config --global user.email "you@example.com"
# !git config --global user.name "Your Name"

# Add your GitHub repository as a remote.
# Replace YOUR_GITHUB_USERNAME and YOUR_REPOSITORY_NAME
# Example: !git remote add origin https://github.com/yourusername/ai-meme-poster-creator.git
# For this step, I cannot fill in your personal GitHub details.
# Please replace the placeholder below with your repository's URL.
# If you're using a private repo or have 2FA, you might need to use a Personal Access Token.

# !git remote add origin https://github.com/YOUR_GITHUB_USERNAME/YOUR_REPOSITORY_NAME.git

# Push your code to GitHub (You'll need to manually execute the push command after adding the remote)
# !git push -u origin main
# You'll likely need to do this manually in your local terminal or follow GitHub's instructions after creating the repo.
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/.git/
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@b1c55b43eae5.(none)')

# %% [markdown]
# **Important:** The `git remote add origin` and `git push` commands need your GitHub credentials, which cannot be handled directly within Colab's command-line interface in a secure and automated way for public repositories. It's best to perform these steps manually on your local machine if you're using a local Git setup, or follow GitHub's specific instructions for linking your repository if you're starting from scratch there.
#
# However, to give you the exact commands for **Colab-specific setup**, if you set up a [Personal Access Token (PAT)](https://docs.github.com/en/authentication/keeping-your-account-and-data-secure/creating-a-personal-access-token) with repo access, you could use it. For instance:
#
# ```bash
# # Replace YOUR_GITHUB_USERNAME, YOUR_PAT and YOUR_REPOSITORY_NAME
# !git remote add origin https://YOUR_GITHUB_USERNAME:YOUR_PAT@github.com/YOUR_GITHUB_USERNAME/YOUR_REPOSITORY_NAME.git
# !git push -u origin main
# ```
#
# Once your `app.py` and `requirements.txt` are pushed to your GitHub repository, we can proceed to deploy it on Streamlit Cloud.
#
# Have you pushed your code to GitHub? Let me know when it's done, and we'll move to Streamlit Cloud deployment!

# %% [markdown]
# ### Push to GitHub
#
# First, make sure you have created an **empty** repository on GitHub (e.g., named `ai-meme-poster-creator`). Copy its URL.
#
# Then, replace the placeholders below with your GitHub username, repository name, and optionally your Personal Access Token (PAT) if needed.

# %%
import os

# --- IMPORTANT: Replace these with your actual GitHub details ---
YOUR_GITHUB_USERNAME = "Anirudh1529" # e.g., "Anirudh1529"
YOUR_REPOSITORY_NAME = "AI-Project-Meme-And-Poster-Creator" # e.g., "ai-meme-poster-creator"

# If you are using a Personal Access Token (PAT) for authentication,
# set it as an environment variable or get it from Colab secrets.
# Otherwise, Git will prompt you for your username/password or use SSH keys.
# For example: YOUR_PAT = userdata.get('GITHUB_PAT')
# If using PAT, uncomment the line below and set the variable
# YOUR_PAT = "YOUR_PERSONAL_ACCESS_TOKEN"

# Add your GitHub repository as a remote
# If using PAT, format will be: https://YOUR_GITHUB_USERNAME:YOUR_PAT@github.com/YOUR_GITHUB_USERNAME/YOUR_REPOSITORY_NAME.git
# Otherwise, it's: https://github.com/YOUR_GITHUB_USERNAME/YOUR_REPOSITORY_NAME.git

# Construct the remote URL
if 'YOUR_PAT' in locals():
    github_remote_url = f"https://{YOUR_GITHUB_USERNAME}:{YOUR_PAT}@github.com/{YOUR_GITHUB_USERNAME}/{YOUR_REPOSITORY_NAME}.git"
else:
    github_remote_url = f"https://github.com/{YOUR_GITHUB_USERNAME}/{YOUR_REPOSITORY_NAME}.git"

# !git remote add origin {github_remote_url}

# Push your code to GitHub
# You might be prompted for your GitHub username and password if not using PAT or SSH
# !git push -u origin main
# Out:
# error: remote origin already exists.
# error: src refspec main does not match any
# error: failed to push some refs to 'https://github.com/YOUR_GITHUB_USERNAME/YOUR_REPOSITORY_NAME.git'

# %%
import os

# --- IMPORTANT: Replace these with your actual GitHub details ---
YOUR_GITHUB_USERNAME = "Anirudh1529" # e.g., "Anirudh1529"
YOUR_REPOSITORY_NAME = "AI-Project-Meme-And-Poster-Creator" # e.g., "ai-meme-poster-creator"

# If you are using a Personal Access Token (PAT) for authentication,
# set it as an environment variable or get it from Colab secrets.
# Otherwise, Git will prompt you for your username/password or use SSH keys.
# For example: YOUR_PAT = userdata.get('GITHUB_PAT')
# If using PAT, uncomment the line below and set the variable
# YOUR_PAT = "YOUR_PERSONAL_ACCESS_TOKEN"

# Add your GitHub repository as a remote
# If using PAT, format will be: https://YOUR_GITHUB_USERNAME:YOUR_PAT@github.com/YOUR_GITHUB_USERNAME/YOUR_REPOSITORY_NAME.git
# Otherwise, it's: https://github.com/YOUR_GITHUB_USERNAME/YOUR_REPOSITORY_NAME.git

# Construct the remote URL
if 'YOUR_PAT' in locals():
    github_remote_url = f"https://{YOUR_GITHUB_USERNAME}:{YOUR_PAT}@github.com/{YOUR_GITHUB_USERNAME}/{YOUR_REPOSITORY_NAME}.git"
else:
    github_remote_url = f"https://github.com/{YOUR_GITHUB_USERNAME}/{YOUR_REPOSITORY_NAME}.git"

# !git remote add origin {github_remote_url}

# Push your code to GitHub
# You might be prompted for your GitHub username and password if not using PAT or SSH
# !git push -u origin main
# Out:
# error: remote origin already exists.
# error: src refspec main does not match any
# error: failed to push some refs to 'https://github.com/YOUR_GITHUB_USERNAME/YOUR_REPOSITORY_NAME.git'

# %%
# Rename the local 'master' branch to 'main'
# !git branch -M main

# Now, try pushing your code to GitHub again
# You might be prompted for your GitHub username and password if not using PAT or SSH
# !git push -u origin main
# Out:
# error: src refspec main does not match any
# error: failed to push some refs to 'https://github.com/YOUR_GITHUB_USERNAME/YOUR_REPOSITORY_NAME.git'

# %% [markdown]
# ### Step 1: Re-commit your changes
#
# **Important**: Go back and run cell `37673136` again. It should now successfully commit your `app.py` and `requirements.txt` files.

# %% [markdown]
# ### Step 2: Remove and Re-add GitHub Remote (to ensure correct URL)
#
# First, we'll remove the potentially incorrect `origin` remote, and then re-add it using the correct details you set up earlier. This ensures that the `git push` command targets the right repository.

# %%
# Remove the existing 'origin' remote
# !git remote remove origin

# Re-add the 'origin' remote using your defined variables
# YOUR_GITHUB_USERNAME and YOUR_REPOSITORY_NAME are already set in Python, we'll use them here.

# Construct the remote URL (re-using logic from cell 5a1c921b or kCRMX750jEao)
# This assumes YOUR_GITHUB_USERNAME and YOUR_REPOSITORY_NAME are correctly defined in an earlier cell.
# If you intend to use a PAT, uncomment and set YOUR_PAT in one of the earlier cells.

YOUR_GITHUB_USERNAME = "Anirudh1529"
YOUR_REPOSITORY_NAME = "AI-Project-Meme-And-Poster-Creator"

# Check if PAT is defined, otherwise assume direct URL
if 'YOUR_PAT' in locals(): # This checks if YOUR_PAT variable exists in the current scope
    # Note: For robust PAT handling, it's better to get from os.environ or userdata.get
    # For simplicity, we'll use a direct string construction here.
    # Make sure YOUR_PAT is actually set in Colab secrets or earlier cells if you use this branch.
    github_remote_url = f"https://{YOUR_GITHUB_USERNAME}:{YOUR_PAT}@github.com/{YOUR_GITHUB_USERNAME}/{YOUR_REPOSITORY_NAME}.git"
else:
    github_remote_url = f"https://github.com/{YOUR_GITHUB_USERNAME}/{YOUR_REPOSITORY_NAME}.git"

# !git remote add origin {github_remote_url}

# Push your code to GitHub
# The local branch was renamed to 'main' in the previous step.
# !git push -u origin main
# Out:
# error: src refspec main does not match any
# error: failed to push some refs to 'https://github.com/Anirudh1529/AI-Project-Meme-And-Poster-Creator.git'

# %%
# Step 1: Re-commit your changes now that Git identity is configured
# This command is based on the one in cell 37673136
# !git add app.py requirements.txt
# !git commit -m "Initial commit: AI Meme & Poster Creator Streamlit app"

# Step 2: Ensure the local branch is 'main'
# This command handles renaming from 'master' to 'main' if necessary
# !git branch -M main

# Step 3: Remove existing remote and re-add it to ensure correct configuration
# This handles cases where the remote might have been added incorrectly or needs to be refreshed
# !git remote remove origin 2>/dev/null || true # Remove if exists, suppress error if not

# Re-add the 'origin' remote using your defined variables
# YOUR_GITHUB_USERNAME and YOUR_REPOSITORY_NAME are assumed to be set from previous cells
YOUR_GITHUB_USERNAME = "Anirudh1529"
YOUR_REPOSITORY_NAME = "AI-Project-Meme-And-Poster-Creator"

# Construct the remote URL (re-using logic from cell 5a1c921b or kCRMX750jEao)
# This assumes YOUR_GITHUB_USERNAME and YOUR_REPOSITORY_NAME are correctly defined in an earlier cell.
# If you intend to use a PAT, uncomment and set YOUR_PAT in one of the earlier cells.
if 'YOUR_PAT' in locals() and YOUR_PAT: # Check if PAT is defined and not empty
    github_remote_url = f"https://{YOUR_GITHUB_USERNAME}:{YOUR_PAT}@github.com/{YOUR_GITHUB_USERNAME}/{YOUR_REPOSITORY_NAME}.git"
else:
    github_remote_url = f"https://github.com/{YOUR_GITHUB_USERNAME}/{YOUR_REPOSITORY_NAME}.git"

# !git remote add origin {github_remote_url}

# Step 4: Push your code to GitHub
# You might be prompted for your GitHub username and password if not using PAT or SSH
# !git push -u origin main
# Out:
# [main (root-commit) b352df7] Initial commit: AI Meme & Poster Creator Streamlit app
#  2 files changed, 104 insertions(+)
#  create mode 100644 app.py
#  create mode 100644 requirements.txt
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# Configure your Git identity
# !git config --global user.email "rajanirudh107@gmail.com" # Replace with your email
# !git config --global user.name "Anirudh1529" # Replace with your name

# %% [markdown]
# After running the cell above to configure your Git identity, please go back to the cell where you tried to commit your changes (the one with `!git commit -m "Initial commit: AI Meme & Poster Creator Streamlit app"`) and **re-run it**.
#
# Once that commit is successful, you can then proceed with adding your GitHub remote and pushing your code as described in the markdown cell below the Git commands. Let me know when you've successfully committed your changes and pushed to GitHub!

# %% [markdown]
# ### Step 1: Create a GitHub Personal Access Token (PAT)
#
# To push to GitHub from Colab without interactive prompts, you'll need a Personal Access Token (PAT). Follow these steps to create one:
#
# 1.  Go to your GitHub settings: **Settings** > **Developer settings** > **Personal access tokens** > **Tokens (classic)**.
# 2.  Click **Generate new token** > **Generate new token (classic)**.
# 3.  Give your token a descriptive **Note** (e.g., "Colab AI Meme Creator").
# 4.  Set an **Expiration** date (e.g., 90 days).
# 5.  Under **Select scopes**, check the **`repo`** checkbox (this grants full control of private repositories, which is usually needed for pushing).
# 6.  Click **Generate token**.
# 7.  **IMPORTANT:** Copy the generated token immediately. You won't be able to see it again!
#
# Once you have your PAT, proceed to the next step.

# %% [markdown]
# ### Step 2: Store your PAT securely in Colab Secrets
#
# Now, store your copied GitHub PAT in Colab's Secrets manager:
#
# 1.  Click the "🔑" icon in the left sidebar of Colab.
# 2.  Click "Add new secret".
# 3.  For the **Name**, type `GITHUB_PAT` (this is important, as our code will look for this name).
# 4.  For the **Value**, paste your GitHub Personal Access Token.
# 5.  Make sure "Notebook access" is enabled for this secret.
#
# After you've saved the secret, run the following cell to ensure it's loaded into your environment.

# %%
import os
from google.colab import userdata

# Access your GitHub PAT from Colab's secrets manager
YOUR_PAT = userdata.get('GITHUB_PAT')

# Verify that the PAT is loaded (optional, remove after verification)
if YOUR_PAT:
    print("GitHub PAT loaded successfully!")
else:
    print("Error: GitHub PAT not found in Colab secrets.")
# Out:
# GitHub PAT loaded successfully!

# %% [markdown]
# ### Step 3: Re-run Git Commands with PAT
#
# Now that your PAT is set up, we'll re-run the Git commands, ensuring the PAT is used for authentication. This time, the `git push` command should succeed.

# %%
# Assume YOUR_GITHUB_USERNAME and YOUR_REPOSITORY_NAME are already defined from previous cells.
# If not, please define them here:
YOUR_GITHUB_USERNAME = "Anirudh1529"
YOUR_REPOSITORY_NAME = "AI-Project-Meme-And-Poster-Creator"

# Remove any existing remote 'origin' to avoid conflicts
# !git remote remove origin 2>/dev/null || true

# Add the 'origin' remote using the PAT for authentication
github_remote_url_with_pat = f"https://{YOUR_GITHUB_USERNAME}:{YOUR_PAT}@github.com/{YOUR_GITHUB_USERNAME}/{YOUR_REPOSITORY_NAME}.git"
# !git remote add origin {github_remote_url_with_pat}

# Ensure the local branch is 'main' (if not already)
# !git branch -M main

# Finally, push your code to GitHub
# !git push -u origin main
# Out:
# remote: Repository not found.
# fatal: repository 'https://github.com/Anirudh1529/AI-Project-Meme-And-Poster-Creator.git/' not found

# %% [markdown]
# Let me know if the push was successful this time! Once your code is on GitHub, we can proceed to deploy it on Streamlit Cloud.

# %% [markdown]
# ### Re-attempting Git Push with PAT
#
# Assuming you have verified that the repository `AI-Project-Meme-And-Poster-Creator` exists and is correctly named on your GitHub account (`Anirudh1529`), I will now re-run the commands to push your code.

# %%
# The variables YOUR_GITHUB_USERNAME, YOUR_REPOSITORY_NAME, and YOUR_PAT are already defined from previous cells.
# We'll use the pre-constructed URL with PAT.

# Remove any existing remote 'origin' to avoid conflicts, and suppress errors if it doesn't exist.
# !git remote remove origin 2>/dev/null || true

# Add the 'origin' remote using the PAT for authentication
github_remote_url_with_pat = f"https://{YOUR_GITHUB_USERNAME}:{YOUR_PAT}@github.com/{YOUR_GITHUB_USERNAME}/{YOUR_REPOSITORY_NAME}.git"
# !git remote add origin {github_remote_url_with_pat}

# Ensure the local branch is 'main'
# !git branch -M main

# Finally, push your code to GitHub
print(f"Attempting to push to GitHub repository: {YOUR_REPOSITORY_NAME}")
# !git push -u origin main

print("Please check your GitHub repository in your browser to confirm the files have been pushed.")
# Out:
# Attempting to push to GitHub repository: AI-Project-Meme-And-Poster-Creator
# remote: Repository not found.
# fatal: repository 'https://github.com/Anirudh1529/AI-Project-Meme-And-Poster-Creator.git/' not found
# Please check your GitHub repository in your browser to confirm the files have been pushed.

# %% [markdown]
# ### Correcting Repository Name and Re-attempting Push
#
# Based on the URL you provided, I've identified a slight difference in the repository name. I will correct this and re-run the Git commands to push your code.

# %%
# Update YOUR_REPOSITORY_NAME to match the exact GitHub repository name
YOUR_REPOSITORY_NAME = "AI-Project-Meme-and-Poster-Creater"

# The variables YOUR_GITHUB_USERNAME and YOUR_PAT are already defined from previous cells.

# Remove any existing remote 'origin' to avoid conflicts, and suppress errors if it doesn't exist.
# !git remote remove origin 2>/dev/null || true

# Add the 'origin' remote using the PAT for authentication
github_remote_url_with_pat = f"https://{YOUR_GITHUB_USERNAME}:{YOUR_PAT}@github.com/{YOUR_GITHUB_USERNAME}/{YOUR_REPOSITORY_NAME}.git"
# !git remote add origin {github_remote_url_with_pat}

# Ensure the local branch is 'main'
# !git branch -M main

# Finally, push your code to GitHub
print(f"Attempting to push to GitHub repository: {YOUR_REPOSITORY_NAME}")
# !git push -u origin main

print("Please check your GitHub repository in your browser to confirm the files have been pushed.")
# Out:
# Attempting to push to GitHub repository: AI-Project-Meme-and-Poster-Creater
# Enumerating objects: 4, done.
# Counting objects: 100% (4/4), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (4/4), 1.82 KiB | 1.82 MiB/s, done.
# Total 4 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/Anirudh1529/AI-Project-Meme-and-Poster-Creater.git
#  * [new branch]      main -> main
# Branch 'main' set up to track remote branch 'main' from 'origin'.
# Please check your GitHub repository in your browser to confirm the files have been pushed.

# %% [markdown]
# Please check your GitHub repository (`https://github.com/Anirudh1529/AI-Project-Meme-and-Poster-Creater`) in your browser to confirm that `app.py` and `requirements.txt` are now present. If it was successful, we can move on to deploying your app on Streamlit Cloud!

# %% [markdown]
# After running the cell above, please check your GitHub repository in your browser to confirm that `app.py` and `requirements.txt` are now present. If it was successful, we can move on to deploying your app on Streamlit Cloud!

# %% [markdown]
# ### Example Images for Testing
#
# Here are some example images that you can download and use to test your Streamlit app. After downloading, you can upload them using the 'Choose an image file' button in your Streamlit app.

# %%
# Download example image 1: Dog playing basketball
# !wget -O dog_basketball.jpg https://i.imgur.com/g7i1K8D.jpeg

# Display the downloaded image
from IPython.display import Image, display
display(Image('dog_basketball.jpg'))
# Out:
# --2026-06-15 14:29:09--  https://i.imgur.com/g7i1K8D.jpeg
# Resolving i.imgur.com (i.imgur.com)... 199.232.192.193, 199.232.196.193
# Connecting to i.imgur.com (i.imgur.com)|199.232.192.193|:443... connected.
# HTTP request sent, awaiting response... 429 Unknown Error
# 2026-06-15 14:29:09 ERROR 429: Unknown Error.

# %%
# Download example image 2: Cat with a ball
# !wget -O cat_ball.jpg https://i.imgur.com/KzD8sBq.jpeg

# Display the downloaded image
from IPython.display import Image, display
display(Image('cat_ball.jpg'))
# Out:
# --2026-06-15 14:29:10--  https://i.imgur.com/KzD8sBq.jpeg
# Resolving i.imgur.com (i.imgur.com)... 199.232.192.193, 199.232.196.193
# Connecting to i.imgur.com (i.imgur.com)|199.232.192.193|:443... connected.
# HTTP request sent, awaiting response... 429 Unknown Error
# 2026-06-15 14:29:10 ERROR 429: Unknown Error.

# %%
# Download example image 3: Humorous scene
# !wget -O funny_scene.jpg https://i.imgur.com/8x2j0gD.jpeg

# Display the downloaded image
from IPython.display import Image, display
display(Image('funny_scene.jpg'))
# Out:
# --2026-06-15 14:29:10--  https://i.imgur.com/8x2j0gD.jpeg
# Resolving i.imgur.com (i.imgur.com)... 199.232.192.193, 199.232.196.193
# Connecting to i.imgur.com (i.imgur.com)|199.232.192.193|:443... connected.
# HTTP request sent, awaiting response... 429 Unknown Error
# 2026-06-15 14:29:10 ERROR 429: Unknown Error.

# %% [markdown]
# You can now use these downloaded images in your Streamlit application by uploading them via the 'Choose an image file' button. Remember to restart your `localtunnel` instance if it's not already running to ensure your Streamlit app is accessible.

# %%
# Download example image 1: Dog playing basketball (from Wikimedia Commons)
# !wget -O dog_basketball.jpg https://upload.wikimedia.org/wikipedia/commons/e/ed/Dog_basketball_team.jpg

# Display the downloaded image
from IPython.display import Image, display
display(Image('dog_basketball.jpg'))
# Out:
# --2026-06-15 14:31:25--  https://upload.wikimedia.org/wikipedia/commons/e/ed/Dog_basketball_team.jpg
# Resolving upload.wikimedia.org (upload.wikimedia.org)... 198.35.26.240, 2620:0:863:ed1a::2:b
# Connecting to upload.wikimedia.org (upload.wikimedia.org)|198.35.26.240|:443... connected.
# HTTP request sent, awaiting response... 429 Too Many Requests (015d12c)
# 2026-06-15 14:31:25 ERROR 429: Too Many Requests (015d12c).

# %%
# Download example image 2: Cat with a ball (from PublicDomainPictures.net)
# !wget -O cat_ball.jpg https://www.publicdomainpictures.net/pictures/100000/velka/playful-kitten-with-ball.jpg

# Display the downloaded image
from IPython.display import Image, display
display(Image('cat_ball.jpg'))
# Out:
# --2026-06-15 14:31:25--  https://www.publicdomainpictures.net/pictures/100000/velka/playful-kitten-with-ball.jpg
# Resolving www.publicdomainpictures.net (www.publicdomainpictures.net)... 172.66.140.55, 172.66.134.60, 2606:4700:10::ac42:863c, ...
# Connecting to www.publicdomainpictures.net (www.publicdomainpictures.net)|172.66.140.55|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.publicdomainpictures.net/error.php [following]
# --2026-06-15 14:31:26--  https://www.publicdomainpictures.net/error.php
# Reusing existing connection to www.publicdomainpictures.net:443.
# HTTP request sent, awaiting response... 403 Forbidden
# 2026-06-15 14:31:26 ERROR 403: Forbidden.

# %%
# Download example image 3: Humorous scene (from PublicDomainPictures.net)
# !wget -O funny_scene.jpg https://www.publicdomainpictures.net/pictures/130000/velka/crazy-man-1437151025b3g.jpg

# Display the downloaded image
from IPython.display import Image, display
display(Image('funny_scene.jpg'))
# Out:
# --2026-06-15 14:31:27--  https://www.publicdomainpictures.net/pictures/130000/velka/crazy-man-1437151025b3g.jpg
# Resolving www.publicdomainpictures.net (www.publicdomainpictures.net)... 172.66.140.55, 172.66.134.60, 2606:4700:10::ac42:863c, ...
# Connecting to www.publicdomainpictures.net (www.publicdomainpictures.net)|172.66.140.55|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.publicdomainpictures.net/error.php [following]
# --2026-06-15 14:31:27--  https://www.publicdomainpictures.net/error.php
# Reusing existing connection to www.publicdomainpictures.net:443.
# HTTP request sent, awaiting response... 403 Forbidden
# 2026-06-15 14:31:27 ERROR 403: Forbidden.

# %% [markdown]
# Once these images are downloaded to your Colab environment, you can use them in your Streamlit application by uploading them via the 'Choose an image file' button. If your Streamlit app isn't running, remember to restart your `localtunnel` instance.
#
# Let me know if these images download successfully and if you're able to use them in your app!

# %% [markdown]
# ### Push Updated `app.py` to GitHub
#
# We need to push the latest `app.py` (where `google.colab` import is commented out) to your GitHub repository. This will trigger Streamlit Cloud to redeploy your application with the corrected code.

# %%
# First, add the updated app.py to staging
# !git add app.py

# Commit the changes
# !git commit -m "Remove google.colab import for Streamlit Cloud deployment"

# Push to GitHub
# The variables YOUR_GITHUB_USERNAME, YOUR_REPOSITORY_NAME, and YOUR_PAT are already defined from previous cells.
# We'll use the pre-constructed URL with PAT if available.

if 'YOUR_PAT' in locals() and YOUR_PAT:
    github_remote_url_with_pat = f"https://{YOUR_GITHUB_USERNAME}:{YOUR_PAT}@github.com/{YOUR_GITHUB_USERNAME}/{YOUR_REPOSITORY_NAME}.git"
    # !git remote set-url origin {github_remote_url_with_pat}

print(f"Attempting to push updated app.py to GitHub repository: {YOUR_REPOSITORY_NAME}")
# !git push -u origin main

print("Please check your Streamlit Cloud logs. Your app should now be redeploying with the corrected code.")
# Out:
# [main 326e01e] Remove google.colab import for Streamlit Cloud deployment
#  1 file changed, 3 insertions(+), 5 deletions(-)
# Attempting to push updated app.py to GitHub repository: AI-Project-Meme-and-Poster-Creater
# Enumerating objects: 5, done.
# Counting objects: 100% (5/5), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 458 bytes | 458.00 KiB/s, done.
# Total 3 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/Anirudh1529/AI-Project-Meme-and-Poster-Creater.git
#    b352df7..326e01e  main -> main
# Branch 'main' set up to track remote branch 'main' from 'origin'.
# Please check your Streamlit Cloud logs. Your app should now be redeploying with the corrected code.
